# %%
from datasets import load_dataset

# Load your dataset
dataset = load_dataset("LanD-FBK/CrisiText", split='train')

# Look at one example
print(dataset[0])
# Out:
# {'set': 'train', 'guidelines': "['avalanche', 'winterweather']", 'scenario_id': 'train-0', 'source': 'FEMA', 'original_description': '* LOCATION...LAKE COUNTY...WESTERN CHAFFEE COUNTY ABOVE 11000\nFEET...THE EASTERN SAN JUAN AND LA GARITA MOUNTAINS ABOVE\n10000 FEET...INCLUDING LEADVILLE...CLIMAX...BONANZA...NORTH\nPASS... CUMBRES PASS AND WOLF CREEK PASS.\n\n* CAUSE AND TIMING...HEAVY SNOW WILL DEVELOP MONDAY AND CONTINUE\nINTO MIDDAY TUESDAY...WITH THE HEAVIEST SNOWFALL OCCURRING\nMONDAY AFTERNOON AND EVENING.\n\n* SNOW ACCUMULATION...8 TO 20 INCHES BY MIDDAY TUESDAY...WITH\nLOCALLY HIGHER SNOW AMOUNTS POSSIBLE ON WEST FACING SLOPES. THIS\nWILL BE A RELATIVELY WET SNOW DUE TO THE SUBTROPICAL MOISTURE\nSOURCE.\n\n* WIND...WEST WINDS 25 TO 35 MPH GUSTING TO AROUND 65 MPH AT\nTIMES ACROSS THE HIGHER ELEVATIONS AND EXPOSED AREAS. THIS\nWILL PRODUCE EXTENSIVE BLOWING AND DRIFTING SNOW.\n\n* IMPACT...SNOW AND AREAS OF BLOWING SNOW WILL REDUCE VISIBILITY\nTO UNDER A MILE AND ROADWAYS WILL
# ...
